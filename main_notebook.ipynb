# %% [markdown]
# # Use this notbook for your 3 choices of APIs

# %%
# Importing requests library

import requests
import pandas as pd

pd.set_option("display.max_rows", 0)

# %%
# 
# 200: Everything went okay and the result has been returned (if any).
# 301: The server is redirecting you to a different endpoint. This can happen when a company switches domain names, or an endpoint name is changed.
# 400: The server thinks you made a bad request. This happens when you don’t send along the right data, among other things.
# 401: You are not properly authenticated.
# 403: The resource you’re trying to access is forbidden: you don’t have the right permissions to get it.
# 404: The resource you tried to access doesn't exist.
# 503: The server can't handle the request.
# full list: https://en.wikipedia.org/wiki/List_of_HTTP_status_codes

# %% [markdown]
# # 1st Dataframe

# %%
import json

response = requests.get("https://xkcd.com/info.0.json")

results = response.json()

print("response:", response.status_code)
# Out:
# response: 200

# %%
print(response.text)
# Out:
# {"month": "10", "num": 2683, "link": "", "year": "2022", "news": "", "safe_title": "Fan Theories", "transcript": "", "alt": "The universe fandom is great. Such sweet and enthusiastic people.", "img": "https://imgs.xkcd.com/comics/fan_theories.png", "title": "Fan Theories", "day": "10"}

# %%
results
# Out:
# {'month': '10',
#  'num': 2683,
#  'link': '',
#  'year': '2022',
#  'news': '',
#  'safe_title': 'Fan Theories',
#  'transcript': '',
#  'alt': 'The universe fandom is great. Such sweet and enthusiastic people.',
#  'img': 'https://imgs.xkcd.com/comics/fan_theories.png',
#  'title': 'Fan Theories',
#  'day': '10'}

# %%
data = pd.DataFrame.from_dict(results, orient="index").transpose()

data
# Out:
#   month   num link  year news    safe_title transcript  \
# 0    10  2683       2022       Fan Theories
#
#                                                  alt  \
# 0  The universe fandom is great. Such sweet and e...
#
#                                              img         title day
# 0  https://imgs.xkcd.com/comics/fan_theories.png  Fan Theories  10

# %% [markdown]
# # 2nd Dataframe: Student chapters

# %%
response = requests.get('https://services2.arcgis.com/5I7u4SJE1vUr79JC/arcgis/rest/services/UniversityChapters_Public/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json')

results = response.json()

print("response:", response.status_code)
# Out:
# response: 200

# %%
#results

# %%
#results['features']
results['features'][0]
# Out:
# {'attributes': {'OBJECTID': 2,
#   'University_Chapter': 'Florida State University',
#   'City': 'Tallahassee',
#   'State': 'FL',
#   'ChapterID': 'FL0110',
#   'MEVR_RD': 'Jarrett Lafferty'},
#  'geometry': {'x': -84.30427263699994, 'y': 30.438110943000027}}

# %%
data_0 = pd.DataFrame.from_dict(results['features'][0], orient= 'index')

for i in range(1, 97):
    data_1 = pd.DataFrame.from_dict(results['features'][i], orient= 'index')
    data_0 = pd.concat([data_0, data_1], axis=0)
    
    data_0

# %%
display(data_0.head())
display(data_0.columns)
# Out:
#             OBJECTID                    University_Chapter         City State  \
# attributes       2.0              Florida State University  Tallahassee    FL
# geometry         NaN                                   NaN          NaN   NaN
# attributes       3.0  Abraham Baldwin Agricultural College       Tifton    GA
# geometry         NaN                                   NaN          NaN   NaN
# attributes       4.0                 University of Georgia       Athens    GA
#
#            ChapterID           MEVR_RD          x          y
# attributes    FL0110  Jarrett Lafferty        NaN        NaN
# geometry         NaN               NaN -84.304273  30.438111
# attributes    GA0020    Brice Crawford        NaN        NaN
# geometry         NaN               NaN -83.510064  31.463418
# attributes    GA0133       Scott James        NaN        NaN
# Index(['OBJECTID', 'University_Chapter', 'City', 'State', 'ChapterID',
#        'MEVR_RD', 'x', 'y'],
#       dtype='object')

# %%
# I will divide the df into two dfs: attributes and geometries. Attributes df will have everything but the 
    #x and y columns.
    # geometry df will have x and y columns.
    
        #Then I will concatenate them on axis=1

attributes= data_0[data_0['x'].isna() == True]
attributes=attributes[["OBJECTID","University_Chapter","City","State","ChapterID","MEVR_RD"]]
attributes.reset_index(inplace=True)

geometry= data_0[data_0['x'].isna() == False]
geometry=geometry[['x','y']]
geometry.reset_index(inplace=True)

student_chapters_df = pd.concat([attributes, geometry], axis=1)

student_chapters_df.drop(['index','index'], inplace=True, axis=1)

student_chapters_df.head()
# Out:
#    OBJECTID                    University_Chapter         City State  \
# 0       2.0              Florida State University  Tallahassee    FL
# 1       3.0  Abraham Baldwin Agricultural College       Tifton    GA
# 2       4.0                 University of Georgia       Athens    GA
# 3       5.0           Georgia Southern University   Statesboro    GA
# 4       6.0               Georgia Tech University      Atlanta    GA
#
#   ChapterID           MEVR_RD          x          y
# 0    FL0110  Jarrett Lafferty -84.304273  30.438111
# 1    GA0020    Brice Crawford -83.510064  31.463418
# 2    GA0133       Scott James -83.383246  33.955464
# 3    GA0144    Brice Crawford -81.779237  32.445146
# 4    GA0147       Scott James -84.403173  33.759509

# %% [markdown]
# # 3rd piece of data

# %%
import json

response = requests.get('https://api.chucknorris.io/jokes/random')

results = response.json()

print("response:", response.status_code)
# Out:
# response: 200

# %%
results
# Out:
# {'categories': [],
#  'created_at': '2020-01-05 13:42:30.480041',
#  'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#  'id': 's2jM0EbWTFe-yMDkvM_JfQ',
#  'updated_at': '2020-01-05 13:42:30.480041',
#  'url': 'https://api.chucknorris.io/jokes/s2jM0EbWTFe-yMDkvM_JfQ',
#  'value': 'one day 7 year old Chuck Norris swam to europe, next day nazi surrendered'}

# %%
results['value']
# Out:
# 'one day 7 year old Chuck Norris swam to europe, next day nazi surrendered'

# %% [markdown]
# # 4th Dataframe

# %%
import json

response = requests.get('https://tenders.guru/api/hu/tenders')

results = response.json()

print("response:", response.status_code)
# Out:
# response: 200

# %%
#results['data']

# %%
data = pd.DataFrame(results['data'])
data.head()
# Out:
#       id        date deadline_date  \
# 0  36077  2021-08-01    2021-08-12
# 1  36073  2021-09-26    2021-10-07
# 2  36067  2021-01-17    2021-01-28
# 3  36060  2021-01-28    2021-03-03
# 4  36059  2021-10-21    2021-11-03
#
#                                                title       category  \
# 0  "Régészeti feltárásokhoz szükséges kézi földmu...  constructions
# 1             Cserepes és Szélmalom utcák felújítása  constructions
# 2   Bölcsőde építése Dömösön – TOP-1.4.1-19-KO1-2019  constructions
# 3                     Építési beruházás - EFOP-2.4.1  constructions
# 4                      Felszíni vízrendezés I. üteme  constructions
#
#                                          description  \
# 0  Vállalkozási keretszerződés régészeti feltárás...
# 1  1. részajánlat: Kisújszállás, Cserepes utca fe...
# 2  Dömösi Szivárvány Óvoda bővítése 8 férőhelyes ...
# 3  Ajánlatkérő az EFOP-2.4.1-16-2017-00060 azonos...
# 4  A belterület védelmét szolgáló egységes, de sz...
#
#                                          phase  \
# 0  E60 - Szerződéskötési-, teljesítési szakasz
# 1  E60 - Szerződéskötési-, teljesítési szakasz
# 2  E60 - Szerződéskötési-, teljesítési szakasz
# 3  E60 - Szerződéskötési-, teljesítési szakasz
# 4  E60 - Szerződéskötési-, teljesítési szakasz
#
#                             phase_en                       place  \
# 0  Contracting and performance phase             HU MAGYARORSZÁG
# 1  Contracting and performance phase  HU322 Jász-Nagykun-Szolnok
# 2  Contracting and performance phase     HU212 Komárom-Esztergom
# 3  Contracting and performance phase                 HU332 Békés
# 4  Contracting and performance phase                 HU211 Fejér
#
#                sid            eid awarded_value awarded_currency  \
# 0  EKR000835312021  8799438370123  299000000.00              HUF
# 1  EKR001148352021  8799640974667   56147040.00              HUF
# 2  EKR000040282021  8799014909259   51809732.00              HUF
# 3  EKR001395772020  8798981911883  204326253.00              HUF
# 4  EKR001305162021  8799742096715  138496654.00              HUF
#
#   awarded_value_eur                                          purchaser  \
# 0         819784.50  {'id': 4895, 'sid': 8796421322032, 'name': 'Sz...
# 1         153941.38  {'id': 118, 'sid': 8796604921136, 'name': 'Kis...
# 2         142049.55  {'id': 4894, 'sid': 8796369876272, 'name': 'Dö...
# 3         560212.36  {'id': 3106, 'sid': 8796376069424, 'name': 'Ku...
# 4         379723.78  {'id': 1589, 'sid': 8796617504048, 'name': 'Na...
#
#                                     type  \
# 0  {'id': '2', 'name': '2', 'slug': '2'}
# 1  {'id': '2', 'name': '2', 'slug': '2'}
# 2  {'id': '2', 'name': '2', 'slug': '2'}
# 3  {'id': '2', 'name': '2', 'slug': '2'}
# 4  {'id': '2', 'name': '2', 'slug': '2'}
#
#                                              awarded deadline_length_days  \
# 0  [{'date': '2021-11-17', 'value_for_two': 29900...                  NaN
# 1  [{'date': '2021-11-17', 'value_for_two': 0, 'v...                   11
# 2  [{'date': '2021-11-17', 'value_for_two': 0, 'v...                   11
# 3  [{'date': '2021-11-17', 'value_for_two': 46361...                  NaN
# 4  [{'date': '2021-11-17', 'value_for_two': 0, 'v...                   13
#
#   indicators
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
nested_columns = ['purchaser','type']

flat = flatten(data, nested_columns)
flat.head()
# Out:
#       id        date deadline_date  \
# 0  36077  2021-08-01    2021-08-12
# 1  36073  2021-09-26    2021-10-07
# 2  36067  2021-01-17    2021-01-28
# 3  36060  2021-01-28    2021-03-03
# 4  36059  2021-10-21    2021-11-03
#
#                                                title       category  \
# 0  "Régészeti feltárásokhoz szükséges kézi földmu...  constructions
# 1             Cserepes és Szélmalom utcák felújítása  constructions
# 2   Bölcsőde építése Dömösön – TOP-1.4.1-19-KO1-2019  constructions
# 3                     Építési beruházás - EFOP-2.4.1  constructions
# 4                      Felszíni vízrendezés I. üteme  constructions
#
#                                          description  \
# 0  Vállalkozási keretszerződés régészeti feltárás...
# 1  1. részajánlat: Kisújszállás, Cserepes utca fe...
# 2  Dömösi Szivárvány Óvoda bővítése 8 férőhelyes ...
# 3  Ajánlatkérő az EFOP-2.4.1-16-2017-00060 azonos...
# 4  A belterület védelmét szolgáló egységes, de sz...
#
#                                          phase  \
# 0  E60 - Szerződéskötési-, teljesítési szakasz
# 1  E60 - Szerződéskötési-, teljesítési szakasz
# 2  E60 - Szerződéskötési-, teljesítési szakasz
# 3  E60 - Szerződéskötési-, teljesítési szakasz
# 4  E60 - Szerződéskötési-, teljesítési szakasz
#
#                             phase_en                       place  \
# 0  Contracting and performance phase             HU MAGYARORSZÁG
# 1  Contracting and performance phase  HU322 Jász-Nagykun-Szolnok
# 2  Contracting and performance phase     HU212 Komárom-Esztergom
# 3  Contracting and performance phase                 HU332 Békés
# 4  Contracting and performance phase                 HU211 Fejér
#
#                sid  ... awarded_value_eur  \
# 0  EKR000835312021  ...         819784.50
# 1  EKR001148352021  ...         153941.38
# 2  EKR000040282021  ...         142049.55
# 3  EKR001395772020  ...         560212.36
# 4  EKR001305162021  ...         379723.78
#
#                                              awarded deadline_length_days  \
# 0  [{'date': '2021-11-17', 'value_for_two': 29900...                  NaN
# 1  [{'date': '2021-11-17', 'value_for_two': 0, 'v...                   11
# 2  [{'date': '2021-11-17', 'value_for_two': 0, 'v...                   11
# 3  [{'date': '2021-11-17', 'value_for_two': 46361...                  NaN
# 4  [{'date': '2021-11-17', 'value_for_two': 0, 'v...                   13
#
#   indicators purchaser_id  purchaser_sid                      purchaser_name  \
# 0        NaN         4895  8796421322032          Szent István Király Múzeum
# 1        NaN          118  8796604921136    Kisújszállás Város Önkormányzata
# 2        NaN         4894  8796369876272           Dömös Község Önkormányzat
# 3        NaN         3106  8796376069424       Kunágota Község Önkormányzata
# 4        NaN         1589  8796617504048  Nagyvenyim Nagyközség Önkormányzat
#
#   type_id type_name type_slug
# 0       2         2         2
# 1       2         2         2
# 2       2         2         2
# 3       2         2         2
# 4       2         2         2
#
# [5 rows x 23 columns]

# %%
flat['awarded']


# from pandas.io.json import json_normalize

# flattened_data = pd.json_normalize(flat['awarded'])

# flattened_data
# Out:
# 0     [{'date': '2021-11-17', 'value_for_two': 29900...
# 1     [{'date': '2021-11-17', 'value_for_two': 0, 'v...
# 2     [{'date': '2021-11-17', 'value_for_two': 0, 'v...
# 3     [{'date': '2021-11-17', 'value_for_two': 46361...
# 4     [{'date': '2021-11-17', 'value_for_two': 0, 'v...
# 5     [{'date': '2021-11-17', 'value_for_two': 78905...
# 6     [{'date': '2021-11-17', 'value_for_two': 0, 'v...
# 7     [{'date': '2021-11-17', 'value_for_two': 0, 'v...
# 8     [{'date': '2021-11-17', 'value_for_two': 48853...
# 9     [{'date': '2021-11-17', 'value_for_two': 33368...
# 10    [{'date': '2021-11-17', 'value_for_two': 19445...
# 11    [{'date': '2021-11-17', 'value_for_two': 30000...
#                             ...
# 88    [{'date': '2021-11-10', 'value_for_two': 29999...
# 89    [{'date': '2021-11-10', 'value_for_two': 0, 'v...
# 90    [{'date': '2021-11-10', 'value_for_two': 0, 'v...
# 91    [{'date': '2021-11-10', 'value_for_two': 0, 'v...
# 92    [{'date': '2021-11-10', 'value_for_two': 0, 'v...
# 93    [{'date': '2021-11-10', 'value_for_two': 0, 'v...
# 94    [{'date': '2021-11-10', 'value_for_two': 59543...
# 95    [{'date': '2021-11-09', 'value_for_two': 0, 'v...
# 96    [{'date': '2021-11-09', 'value_for_two': 0, 'v...
# 97    [{'date': '2021-11-09', 'value_for_two': 0, 'v...
# 98    [{'date': '2021-11-09', 'value_for_two': 57586...
# 99    [{'date': '2021-11-09', 'value_for_two': 0, 'v...
# Name: awarded, Length: 100, dtype: object
